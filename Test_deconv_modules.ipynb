# %%
from modules import symfn
import sympy as sp
import numpy as np
from modules import numfn
from modules import constants as cnst
from modules import solve_sdos as sdos
from modules import solve_sdos_adv as advsdos
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Fermi function

# %%
y=symfn.fermi()
dy=y.diff(symfn.V,1)
fn_dy=sp.lambdify((symfn.E,symfn.V, symfn.T),dy,"numpy")

# %%
NV=int(4000)
V=np.linspace(-0.01,0.01,NV)

plot(V,fn_dy(-0.001,V,2))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Tip density of states

# %%
rhot=symfn.bcs_dos()

# %%
rhot
# Out:
# (E - V)*cos(atan2(2.0*gamma*(E - V) - im(delta**2.0) + im((E - V)**2.0), -re(delta**2.0) + re((E - V)**2.0))/2)*sign(E - V)/((-re(delta**2.0) + re((E - V)**2.0))**2 + (2.0*gamma*(E - V) - im(delta**2.0) + im((E - V)**2.0))**2)**(1/4)

# %%
numfn.fn_fermi(0.01,0.05,2)
# Out:
# 1.0

# %%
E=np.linspace(-0.01,0.01,1000)
figure()
plot(E,numfn.fn_fermi(E,0.005,2))
plot(E,numfn.dfermi(E,0.005,2)/max(numfn.dfermi(E,0.005,2)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
(symfn.fermi()).diff(symfn.V,1)
# Out:
# 11604.5211854499*exp(11604.5211854499*(E - V)/T)/(T*(exp(11604.5211854499*(E - V)/T) + 1)**2)

# %%
E=np.linspace(-0.01,0.01,1000)
figure()
plot(E,numfn.fn_bcs_dos(E,0.00,1e-4,1.28e-3))
plot(E,numfn.fn_dbcs_dos(E,0.00,1e-4,1.28e-3)/max(numfn.fn_dbcs_dos(E,0.00,1e-4,1.28e-3)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
C=sdos.get_mat(E,1e-4,1.28e-3,2)

# %%
figure()
imshow(C,origin="lower")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
D=np.matrix(E)

# %%
D.shape
# Out:
# (1, 1000)

# %%
data=np.loadtxt("./Data/data.txt")
V=data[:,0]
dIdV=data[:,1]

# %%
sdos=sdos.get_sdos(V,dIdV,gamma=1e-4,delta=1.28e-3,T=2.1)

# %%
E=np.linspace(min(V),max(V),3000)

# %%
sdos?

# %%
figure()
plot(E,array(sdos).flatten())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rdidv=advsdos.get_rec_dIdV(V,1e-4,1.28e-3,2.1,dIdV)

# %%
figure()
plot(V,dIdV)
plot(V,rdidv)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from scipy.optimize import curve_fit

# %%
curve_fit?

# %%
lambda?
# Out:
# Object `lambda` not found.
